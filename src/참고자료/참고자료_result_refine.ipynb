# %%
import pandas as pd
from google.colab import drive

drive.mount('/content/drive')
file_path = '/content/drive/MyDrive/'

tr = pd.read_csv(file_path + 'TPTN.csv')
fs = pd.read_csv(file_path + 'FPFN.csv')

tr.info()
# Out:
# Mounted at /content/drive
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76569 entries, 0 to 76568
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    66935 non-null  object
#  1   label   66935 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 1.2+ MB

# %%
fs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76569 entries, 0 to 76568
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   text         9634 non-null   object
#  1   real_label   9634 non-null   float64
#  2   wrong_label  9634 non-null   float64
# dtypes: float64(2), object(1)
# memory usage: 1.8+ MB

# %%
tr.isnull().sum()
# Out:
# text     9634
# label    9634
# dtype: int64

# %%
fs.isnull().sum()
# Out:
# text           66935
# real_label     66935
# wrong_label    66935
# dtype: int64

# %%
tr = tr.dropna()
tr.isnull().sum()
# Out:
# text     0
# label    0
# dtype: int64

# %%
tr.describe()
# Out:
#               label
# count  66935.000000
# mean       0.565145
# std        0.495742
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000

# %%
fs = fs.dropna()
fs.isnull().sum()
# Out:
# text           0
# real_label     0
# wrong_label    0
# dtype: int64

# %%
fs.describe()
# Out:
#         real_label  wrong_label
# count  9634.000000  9634.000000
# mean      0.457131     0.542869
# std       0.498185     0.498185
# min       0.000000     0.000000
# 25%       0.000000     0.000000
# 50%       0.000000     1.000000
# 75%       1.000000     1.000000
# max       1.000000     1.000000

# %%
tr.to_csv(file_path+'TPTN_refine.csv', encoding = 'utf-8-sig', index = False)
fs.to_csv(file_path+'FPFN_refine.csv', encoding = 'utf-8-sig', index = False)
